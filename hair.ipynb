# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalAveragePooling2D, Lambda, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import cv2
from PIL import Image
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\keras_preprocessing\image\affine_transformations.py:13: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.6)
#   import scipy

# %%
train_imgs_path    = '../datasets/unbraid/img/train'
train_sketchs_path = '../datasets/unbraid/sketch/train'
val_imgs_path      = '../datasets/unbraid/img/test'
val_sketchs_path   = '../datasets/unbraid/sketch/test'

img_height, img_width = 64, 64  # resize shape
channels = 3  # use 3 for RGB, or 1 for grayscale

def get_id(filename):
    base = os.path.splitext(filename)[0]
    return base.split('_')[-1]

def load_data(img_path, sketch_path):
    img_files = [f for f in os.listdir(img_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    sketch_files = [f for f in os.listdir(sketch_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    
    sketch_dict = { get_id(sf): sf for sf in sketch_files }
    
    images, sketches, labels = [], [], []
    
    for img_filename in img_files:
        img_id = get_id(img_filename)
        if img_id in sketch_dict:
            full_img_path = os.path.join(img_path, img_filename)
            full_sketch_path = os.path.join(sketch_path, sketch_dict[img_id])
            
            sketch_pil = Image.open(full_sketch_path).convert('RGB')  # 'L' for grayscale
            sketch_pil = sketch_pil.resize((img_width, img_height))
            sketch_arr = np.array(sketch_pil, dtype=np.float32) / 255.0

            img_pil = Image.open(full_img_path).convert('RGB')
            img_pil = img_pil.resize((img_width, img_height))
            img_arr = np.array(img_pil, dtype=np.float32) / 255.0
            
            images.append(img_arr)
            sketches.append(sketch_arr)
            labels.append(img_id)
    
    return np.array(images, dtype=np.float32), np.array(sketches, dtype=np.float32), np.array(labels)

# Load training and validation data
train_images, train_sketches, train_labels = load_data(train_imgs_path, train_sketchs_path)
val_images, val_sketches, val_labels = load_data(val_imgs_path, val_sketchs_path)
print("Training samples:", train_images.shape)
print("Validation samples:", val_images.shape)
# Out:
# Training samples: (3000, 64, 64, 3)
# Validation samples: (466, 64, 64, 3)

# %%
def embedding_network(input_shape=(64, 64, 1), embedding_dim=128, model_name="cnn_encoder"):
    inputs = layers.Input(shape=input_shape)
    
    # Initial convolution block
    x = layers.Conv2D(64, (3,3), padding="same", use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(64, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)  # Output shape: (32, 32, 64)
    
    # Residual block 1
    shortcut = x
    x = layers.Conv2D(128, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(128, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    # Adjust shortcut to match number of filters (128)
    shortcut = layers.Conv2D(128, (1,1), padding="same", use_bias=False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)  # Output shape: (16, 16, 128)
    
    # Residual block 2
    shortcut = x
    x = layers.Conv2D(256, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(256, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    # Adjust shortcut to match number of filters (256)
    shortcut = layers.Conv2D(256, (1,1), padding="same", use_bias=False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)  # Output shape: (8, 8, 256)
    
    # Global average pooling to flatten spatial dimensions
    x = layers.GlobalAveragePooling2D()(x)
    
    # Final dense layer to produce the embedding vector
    x = layers.Dense(embedding_dim, use_bias=False)(x)
    outputs = tf.math.l2_normalize(x, axis=1)
    
    return models.Model(inputs, outputs, name=model_name)
img_shape = (img_height, img_width, channels)
sketch_shape = (img_height, img_width, channels)


image_encoder = embedding_network(img_shape, model_name='image_encoder')
sketch_encoder = embedding_network(sketch_shape, model_name='sketch_encoder')

# %%
from tensorflow.keras.optimizers import Adam

# Siamese-like model
img_input = Input(img_shape)
sketch_input = Input(img_shape)

img_emb = image_encoder(img_input)
sketch_emb = sketch_encoder(sketch_input)

# Cosine similarity-based loss
def cosine_similarity_loss(y_true, y_pred):
    img_emb, sketch_emb = y_pred[:, :128], y_pred[:, 128:]
    cosine_sim = tf.reduce_sum(img_emb * sketch_emb, axis=1)
    return 1 - cosine_sim  # minimize distance => maximize similarity

combined_output = tf.keras.layers.concatenate([img_emb, sketch_emb])

siamese_model = Model([img_input, sketch_input], combined_output)
siamese_model.compile(optimizer=Adam(1e-4), loss=cosine_similarity_loss)

# Dummy labels for compatibility
dummy_labels = np.zeros((train_images.shape[0], 1))

# Train the model
siamese_model.fit(
    [train_images, train_sketches],
    dummy_labels,
    epochs=20,
    batch_size=8,
    validation_data=([val_images, val_sketches], np.zeros((val_images.shape[0], 1)))
)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 14s 15ms/step - loss: 0.0349 - val_loss: 0.0430
# Epoch 2/20
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 3/20
# 375/375 [==============================] - 5s 14ms/step - loss: 9.1372e-04 - val_loss: 0.0011
# Epoch 4/20
# 375/375 [==============================] - 5s 14ms/step - loss: 6.3413e-04 - val_loss: 8.5378e-04
# Epoch 5/20
# 375/375 [==============================] - 5s 14ms/step - loss: 4.6786e-04 - val_loss: 6.3848e-04
# Epoch 6/20
# 375/375 [==============================] - 5s 14ms/step - loss: 3.5937e-04 - val_loss: 5.1568e-04
# Epoch 7/20
# 375/375 [==============================] - 5s 14ms/step - loss: 2.8569e-04 - val_loss: 4.0753e-04
# Epoch 8/20
# 375/375 [==============================] - 5s 14ms/step - loss: 2.2924e-04 - val_loss: 3.9185e-04
# Epoch 9/20
# 375/375 [==============================] - 5s 14ms/step - loss: 1.9020e-04 - val_loss: 3.1583e-04
# Epoch 10/20
# 375/375 [==============================] - 5s 14ms/step - loss: 1.5990e-04 - val_loss: 3.1750e-04
# Epoch 11/20
# 375/375 [==============================] - 5s 14ms/step - loss: 1.3308e-04 - val_loss: 2.2182e-04
# Epoch 12/20
# 375/375 [==============================] - 5s 14ms/step - loss: 1.1350e-04 - val_loss: 1.9049e-04
# Epoch 13/20
# 375/375 [==============================] - 5s 14ms/step - loss: 9.7489e-05 - val_loss: 1.9811e-04
# Epoch 14/20
# 375/375 [==============================] - 5s 14ms/step - loss: 8.4200e-05 - val_loss: 1.6613e-04
# Epoch 15/20
# 375/375 [==============================] - 5s 14ms/step - loss: 7.3387e-05 - val_loss: 1.3613e-04
# Epoch 16/20
# 375/375 [==============================] - 5s 14ms/step - loss: 6.3334e-05 - val_loss: 1.2617e-04
# Epoch 17/20
# 375/375 [==============================] - 5s 14ms/step - loss: 5.6505e-05 - val_loss: 1.2802e-04
# Epoch 18/20
# 375/375 [==============================] - 5s 14ms/step - loss: 5.0170e-05 - val_loss: 1.0728e-04
# Epoch 19/20
# 375/375 [==============================] - 5s 14ms/step - loss: 4.4274e-05 - val_loss: 1.1035e-04
# Epoch 20/20
# 375/375 [==============================] - 5s 14ms/step - loss: 3.9170e-05 - val_loss: 9.4196e-05

# %%
train_image_emb = image_encoder.predict(train_images, batch_size=32)
train_sketch_emb = sketch_encoder.predict(train_sketches, batch_size=32)

val_image_emb = image_encoder.predict(val_images, batch_size=32)
val_sketch_emb = sketch_encoder.predict(val_sketches, batch_size=32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input

def retrieval_network(input_dim=128, output_dim=128, model_name="retrieval_model"):
    inputs = layers.Input(shape=(input_dim,))
    
    # Initial dense block
    x = layers.Dense(512, use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)

    # Residual Dense Block 1
    shortcut = layers.Dense(512, use_bias=False)(x)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Dense(512, use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Dense(512, use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)

    # Residual Dense Block 2
    shortcut = layers.Dense(256, use_bias=False)(x)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Dense(256, use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Dense(256, use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)

    # Final embedding projection
    outputs = layers.Dense(output_dim)(x)  # no activation

    return models.Model(inputs, outputs, name=model_name)
# Example usage:
retrieval_model = retrieval_network(input_dim=train_sketch_emb.shape[1],
                                    output_dim=train_image_emb.shape[1])

retrieval_model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse')

# %%
retrieval_model.fit(
    train_sketch_emb, train_image_emb,
    epochs=50,
    batch_size=16,
    validation_data=(val_sketch_emb, val_image_emb)
)
# Out:
# Epoch 1/50
# 188/188 [==============================] - 2s 7ms/step - loss: 0.8329 - val_loss: 0.0797
# Epoch 2/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.5486 - val_loss: 0.0984
# Epoch 3/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.3592 - val_loss: 0.0730
# Epoch 4/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.1918 - val_loss: 0.0817
# Epoch 5/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0989 - val_loss: 0.0786
# Epoch 6/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0554 - val_loss: 0.0500
# Epoch 7/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0365 - val_loss: 0.0318
# Epoch 8/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0257 - val_loss: 0.0192
# Epoch 9/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0209 - val_loss: 0.0151
# Epoch 10/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0168 - val_loss: 0.0109
# Epoch 11/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0132 - val_loss: 0.0081
# Epoch 12/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0111 - val_loss: 0.0064
# Epoch 13/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0093 - val_loss: 0.0054
# Epoch 14/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0079 - val_loss: 0.0044
# Epoch 15/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0035
# Epoch 16/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0032
# Epoch 17/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0026
# Epoch 18/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 19/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 20/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 21/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 22/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 23/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 24/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 25/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0018 - val_loss: 8.6627e-04
# Epoch 26/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0016 - val_loss: 8.0227e-04
# Epoch 27/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0015 - val_loss: 7.2891e-04
# Epoch 28/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 5.6706e-04
# Epoch 29/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 5.8376e-04
# Epoch 30/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 4.8977e-04
# Epoch 31/50
# 188/188 [==============================] - 1s 6ms/step - loss: 8.8053e-04 - val_loss: 4.4313e-04
# Epoch 32/50
# 188/188 [==============================] - 1s 6ms/step - loss: 8.5159e-04 - val_loss: 3.9823e-04
# Epoch 33/50
# 188/188 [==============================] - 1s 6ms/step - loss: 7.3371e-04 - val_loss: 3.7273e-04
# Epoch 34/50
# 188/188 [==============================] - 1s 6ms/step - loss: 6.4808e-04 - val_loss: 3.1952e-04
# Epoch 35/50
# 188/188 [==============================] - 1s 6ms/step - loss: 6.0023e-04 - val_loss: 2.8034e-04
# Epoch 36/50
# 188/188 [==============================] - 1s 6ms/step - loss: 5.7084e-04 - val_loss: 2.5429e-04
# Epoch 37/50
# 188/188 [==============================] - 1s 6ms/step - loss: 4.9436e-04 - val_loss: 2.0732e-04
# Epoch 38/50
# 188/188 [==============================] - 1s 6ms/step - loss: 4.2968e-04 - val_loss: 1.9029e-04
# Epoch 39/50
# 188/188 [==============================] - 1s 6ms/step - loss: 3.8679e-04 - val_loss: 1.5156e-04
# Epoch 40/50
# 188/188 [==============================] - 1s 6ms/step - loss: 3.2863e-04 - val_loss: 1.4148e-04
# Epoch 41/50
# 188/188 [==============================] - 1s 6ms/step - loss: 3.1036e-04 - val_loss: 1.4072e-04
# Epoch 42/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.7425e-04 - val_loss: 1.0694e-04
# Epoch 43/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.6465e-04 - val_loss: 1.0569e-04
# Epoch 44/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.4281e-04 - val_loss: 8.2488e-05
# Epoch 45/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.0569e-04 - val_loss: 6.5818e-05
# Epoch 46/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.8793e-04 - val_loss: 6.5090e-05
# Epoch 47/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.6776e-04 - val_loss: 5.9495e-05
# Epoch 48/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.5192e-04 - val_loss: 5.1662e-05
# Epoch 49/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.4002e-04 - val_loss: 5.1857e-05
# Epoch 50/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.3792e-04 - val_loss: 5.3105e-05

# %%
# Predict image embeddings from sketch embeddings
predicted_img_emb = retrieval_model.predict(val_sketch_emb)

# Now find closest embeddings in gallery using efficient distance calculation:
from sklearn.metrics.pairwise import euclidean_distances

distances = euclidean_distances(predicted_img_emb, val_image_emb)
top_k = 5  # choose top-5 or any K you prefer

# Get top-K predictions for each sketch
top_k_indices = np.argsort(distances, axis=1)[:, :top_k]

# Calculate recall metrics
correct_matches = np.arange(len(val_sketch_emb)).reshape(-1,1)
recall_at_k = np.mean([correct_matches[i] in top_k_indices[i] for i in range(len(val_sketch_emb))])

print(f"Recall@{top_k}: {recall_at_k:.4f}")
# Out:
# Recall@5: 0.0086

# %%
image_encoder.save('models/image_encoder.keras')
sketch_encoder.save('models/sketch_encoder.keras')
retrieval_model.save('models/retrieval_model.keras')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
n_samples_fit = val_image_emb.shape[0]
n_neighbors = min(1250, n_samples_fit)

nbrs = NearestNeighbors(n_neighbors=n_neighbors).fit(val_image_emb)

count_recall = np.zeros(n_neighbors, dtype=int)
num_queries = val_sketches.shape[0]

# Compute embeddings for sketches (queries)
query_embeddings = sketch_encoder.predict(val_sketches, batch_size=32)

for idx, query_emb in enumerate(query_embeddings):
    distances, indices = nbrs.kneighbors([query_emb])
    correct_idx = idx  # assuming data is matched by index
    
    rank_found = np.where(indices[0] == correct_idx)[0]
    if len(rank_found) > 0:
        rank = rank_found[0]
        count_recall[rank] += 1
        print(f"Query {idx}: Found correct match at rank {rank+1}")
    else:
        print(f"Query {idx}: Not found in top {n_neighbors}.")

# Calculate cumulative recall
cumulative_recall = np.cumsum(count_recall)

# Safely computing recall metrics with checks:
recall_at_1 = cumulative_recall[0] / num_queries if n_neighbors >= 1 else 0
recall_at_5 = cumulative_recall[4] / num_queries if n_neighbors >= 5 else 0
recall_at_10 = cumulative_recall[9] / num_queries if n_neighbors >= 10 else 0

print(f"\nRecall@1: {recall_at_1:.4f}")
print(f"Recall@5: {recall_at_5:.4f}")
print(f"Recall@10: {recall_at_10:.4f}")
# Out:
# Query 0: Found correct match at rank 276
# Query 1: Found correct match at rank 439
# Query 2: Found correct match at rank 431
# Query 3: Found correct match at rank 166
# Query 4: Found correct match at rank 234
# Query 5: Found correct match at rank 62
# Query 6: Found correct match at rank 67
# Query 7: Found correct match at rank 291
# Query 8: Found correct match at rank 74
# Query 9: Found correct match at rank 422
# Query 10: Found correct match at rank 317
# Query 11: Found correct match at rank 262
# Query 12: Found correct match at rank 461
# Query 13: Found correct match at rank 161
# Query 14: Found correct match at rank 146
# Query 15: Found correct match at rank 261
# Query 16: Found correct match at rank 341
# Query 17: Found correct match at rank 220
# Query 18: Found correct match at rank 399
# Query 19: Found correct match at rank 348
# Query 20: Found correct match at rank 8
# Query 21: Found correct match at rank 146
# Query 22: Found correct match at rank 363
# Query 23: Found correct match at rank 455
# Query 24: Found correct match at rank 57
# Query 25: Found correct match at rank 135
# Query 26: Found correct match at rank 324
# Query 27: Found correct match at rank 184
# Query 28: Found correct match at rank 61
# Query 29: Found correct match at rank 271
# Query 30: Found correct match at rank 68
# Query 31: Found correct match at rank 100
# Query 32: Found correct match at rank 166
# Query 33: Found correct match at rank 256
# Query 34: Found correct match at rank 38
# Query 35: Found correct match at rank 1
# Query 36: Found correct match at rank 4
# Query 37: Found correct match at rank 192
# Query 38: Found correct match at rank 126
# Query 39: Found correct match at rank 408
# Query 40: Found correct match at rank 353
# Query 41: Found correct match at rank 81
# Query 42: Found correct match at rank 200
# Query 43: Found correct match at rank 288
# Query 44: Found correct match at rank 10
# Query 45: Found correct match at rank 460
# Query 46: Found correct match at rank 387
# Query 47: Found correct match at rank 65
# Query 48: Found correct match at rank 409
# Query 49: Found correct match at rank 373
# Query 50: Found correct match at rank 3
# Query 51: Found correct match at rank 13
# Query 52: Found correct match at rank 53
# Query 53: Found correct match at rank 10
# Query 54: Found correct match at rank 19
# Query 55: Found correct match at rank 87
# Query 56: Found correct match at rank 280
# Query 57: Found correct match at rank 335
# Query 58: Found correct match at rank 429
# Query 59: Found correct match at rank 352
# Query 60: Found correct match at rank 285
# Query 61: Found correct match at rank 422
# Query 62: Found correct match at rank 153
# Query 63: Found correct match at rank 218
# Query 64: Found correct match at rank 131
# Query 65: Found correct match at rank 41
# Query 66: Found correct match at rank 48
# Query 67: Found correct match at rank 130
# Query 68: Found correct match at rank 151
# Query 69: Found correct match at rank 198
# Query 70: Found correct match at rank 386
# Query 71: Found correct match at rank 73
# Query 72: Found correct match at rank 419
# Query 73: Found correct match at rank 298
# Query 74: Found correct match at rank 363
# Query 75: Found correct match at rank 408
# Query 76: Found correct match at rank 268
# Query 77: Found correct match at rank 276
# Query 78: Found correct match at rank 425
# Query 79: Found correct match at rank 225
# Query 80: Found correct match at rank 323
# Query 81: Found correct match at rank 452
# Query 82: Found correct match at rank 169
# Query 83: Found correct match at rank 105
# Query 84: Found correct match at rank 314
# Query 85: Found correct match at rank 238
# Query 86: Found correct match at rank 127
# Query 87: Found correct match at rank 342
# Query 88: Found correct match at rank 5
# Query 89: Found correct match at rank 284
# Query 90: Found correct match at rank 312
# Query 91: Found correct match at rank 250
# Query 92: Found correct match at rank 392
# Query 93: Found correct match at rank 289
# Query 94: Found correct match at rank 121
# Query 95: Found correct match at rank 419
# Query 96: Found correct match at rank 240
# Query 97: Found correct match at rank 206
# Query 98: Found correct match at rank 323
# Query 99: Found correct match at rank 120
# Query 100: Found correct match at rank 87
# Query 101: Found correct match at rank 271
# Query 102: Found correct match at rank 289
# Query 103: Found correct match at rank 83
# Query 104: Found correct match at rank 315
# Query 105: Found correct match at rank 230
# Query 106: Found correct match at rank 391
# Query 107: Found correct match at rank 404
# Query 108: Found correct match at rank 421
# Query 109: Found correct match at rank 4
# Query 110: Found correct match at rank 151
# Query 111: Found correct match at rank 20
# Query 112: Found correct match at rank 68
# Query 113: Found correct match at rank 47
# Query 114: Found correct match at rank 3
# Query 115: Found correct match at rank 83
# Query 116: Found correct match at rank 243
# Query 117: Found correct match at rank 178
# Query 118: Found correct match at rank 44
# Query 119: Found correct match at rank 373
# Query 120: Found correct match at rank 149
# Query 121: Found correct match at rank 8
# Query 122: Found correct match at rank 217
# Query 123: Found correct match at rank 305
# Query 124: Found correct match at rank 68
# Query 125: Found correct match at rank 455
# Query 126: Found correct match at rank 144
# Query 127: Found correct match at rank 251
# Query 128: Found correct match at rank 133
# Query 129: Found correct match at rank 100
# Query 130: Found correct match at rank 231
# Query 131: Found correct match at rank 391
# Query 132: Found correct match at rank 223
# Query 133: Found correct match at rank 237
# Query 134: Found correct match at rank 441
# Query 135: Found correct match at rank 36
# Query 136: Found correct match at rank 56
# Query 137: Found correct match at rank 368
# Query 138: Found correct match at rank 253
# Query 139: Found correct match at rank 127
# Query 140: Found correct match at rank 119
# Query 141: Found correct match at rank 40
# Query 142: Found correct match at rank 19
# Query 143: Found correct match at rank 138
# Query 144: Found correct match at rank 295
# Query 145: Found correct match at rank 237
# Query 146: Found correct match at rank 27
# Query 147: Found correct match at rank 179
# Query 148: Found correct match at rank 194
# Query 149: Found correct match at rank 194
# Query 150: Found correct match at rank 132
# Query 151: Found correct match at rank 204
# Query 152: Found correct match at rank 29
# Query 153: Found correct match at rank 382
# Query 154: Found correct match at rank 28
# Query 155: Found correct match at rank 244
# Query 156: Found correct match at rank 22
# Query 157: Found correct match at rank 410
# Query 158: Found correct match at rank 64
# Query 159: Found correct match at rank 328
# Query 160: Found correct match at rank 265
# Query 161: Found correct match at rank 109
# Query 162: Found correct match at rank 216
# Query 163: Found correct match at rank 420
# Query 164: Found correct match at rank 408
# Query 165: Found correct match at rank 418
# Query 166: Found correct match at rank 441
# Query 167: Found correct match at rank 8
# Query 168: Found correct match at rank 43
# Query 169: Found correct match at rank 329
# Query 170: Found correct match at rank 247
# Query 171: Found correct match at rank 206
# Query 172: Found correct match at rank 188
# Query 173: Found correct match at rank 347
# Query 174: Found correct match at rank 351
# Query 175: Found correct match at rank 351
# Query 176: Found correct match at rank 236
# Query 177: Found correct match at rank 285
# Query 178: Found correct match at rank 190
# Query 179: Found correct match at rank 105
# Query 180: Found correct match at rank 291
# Query 181: Found correct match at rank 130
# Query 182: Found correct match at rank 414
# Query 373: Found correct match at rank 430
# Query 374: Found correct match at rank 466
# Query 375: Found correct match at rank 375
# Query 376: Found correct match at rank 411
# Query 377: Found correct match at rank 296
# Query 378: Found correct match at rank 398
# Query 379: Found correct match at rank 45
# Query 380: Found correct match at rank 224
# Query 381: Found correct match at rank 447
# Query 382: Found correct match at rank 445
# Query 383: Found correct match at rank 206
# Query 384: Found correct match at rank 311
# Query 385: Found correct match at rank 128
# Query 386: Found correct match at rank 215
# Query 387: Found correct match at rank 44
# Query 388: Found correct match at rank 129
# Query 389: Found correct match at rank 98
# Query 390: Found correct match at rank 379
# Query 391: Found correct match at rank 346
# Query 392: Found correct match at rank 319
# Query 393: Found correct match at rank 39
# Query 394: Found correct match at rank 406
# Query 395: Found correct match at rank 58
# Query 396: Found correct match at rank 287
# Query 397: Found correct match at rank 182
# Query 398: Found correct match at rank 403
# Query 399: Found correct match at rank 460
# Query 400: Found correct match at rank 247
# Query 401: Found correct match at rank 79
# Query 402: Found correct match at rank 234
# Query 403: Found correct match at rank 452
# Query 404: Found correct match at rank 237
# Query 405: Found correct match at rank 135
# Query 406: Found correct match at rank 290
# Query 407: Found correct match at rank 134
# Query 408: Found correct match at rank 145
# Query 409: Found correct match at rank 204
# Query 410: Found correct match at rank 332
# Query 411: Found correct match at rank 450
# Query 412: Found correct match at rank 22
# Query 413: Found correct match at rank 14
# Query 414: Found correct match at rank 370
# Query 415: Found correct match at rank 461
# Query 416: Found correct match at rank 262
# Query 417: Found correct match at rank 339
# Query 418: Found correct match at rank 415
# Query 419: Found correct match at rank 357
# Query 420: Found correct match at rank 153
# Query 421: Found correct match at rank 391
# Query 422: Found correct match at rank 420
# Query 423: Found correct match at rank 454
# Query 424: Found correct match at rank 25
# Query 425: Found correct match at rank 387
# Query 426: Found correct match at rank 302
# Query 427: Found correct match at rank 85
# Query 428: Found correct match at rank 285
# Query 429: Found correct match at rank 102
# Query 430: Found correct match at rank 318
# Query 431: Found correct match at rank 438
# Query 432: Found correct match at rank 405
# Query 433: Found correct match at rank 258
# Query 434: Found correct match at rank 78
# Query 435: Found correct match at rank 314
# Query 436: Found correct match at rank 416
# Query 437: Found correct match at rank 110
# Query 438: Found correct match at rank 48
# Query 439: Found correct match at rank 104
# Query 440: Found correct match at rank 355
# Query 441: Found correct match at rank 346
# Query 442: Found correct match at rank 61
# Query 443: Found correct match at rank 88
# Query 444: Found correct match at rank 402
# Query 445: Found correct match at rank 398
# Query 446: Found correct match at rank 429
# Query 447: Found correct match at rank 302
# Query 448: Found correct match at rank 384
# Query 449: Found correct match at rank 350
# Query 450: Found correct match at rank 58
# Query 451: Found correct match at rank 425
# Query 452: Found correct match at rank 328
# Query 453: Found correct match at rank 290
# Query 454: Found correct match at rank 55
# Query 455: Found correct match at rank 367
# Query 456: Found correct match at rank 164
# Query 457: Found correct match at rank 12
# Query 458: Found correct match at rank 287
# Query 459: Found correct match at rank 14
# Query 460: Found correct match at rank 294
# Query 461: Found correct match at rank 139
# Query 462: Found correct match at rank 296
# Query 463: Found correct match at rank 257
# Query 464: Found correct match at rank 422
# Query 465: Found correct match at rank 150
#
# Recall@1: 0.0021
# Recall@5: 0.0193
# Recall@10: 0.0322
