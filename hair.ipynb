# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalAveragePooling2D, Lambda, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import cv2
from PIL import Image
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\keras_preprocessing\image\affine_transformations.py:13: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.6)
#   import scipy

# %%
train_imgs_path    = '../datasets/unbraid/img/train'
train_sketchs_path = '../datasets/unbraid/sketch/train'
val_imgs_path      = '../datasets/unbraid/img/test'
val_sketchs_path   = '../datasets/unbraid/sketch/test'

img_height, img_width = 64, 64  # resize shape
channels = 3  # use 3 for RGB, or 1 for grayscale

def get_id(filename):
    base = os.path.splitext(filename)[0]
    return base.split('_')[-1]

def load_data(img_path, sketch_path):
    img_files = [f for f in os.listdir(img_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    sketch_files = [f for f in os.listdir(sketch_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    
    sketch_dict = { get_id(sf): sf for sf in sketch_files }
    
    images, sketches, labels = [], [], []
    
    for img_filename in img_files:
        img_id = get_id(img_filename)
        if img_id in sketch_dict:
            full_img_path = os.path.join(img_path, img_filename)
            full_sketch_path = os.path.join(sketch_path, sketch_dict[img_id])
            
            sketch_pil = Image.open(full_sketch_path).convert('RGB')  # 'L' for grayscale
            sketch_pil = sketch_pil.resize((img_width, img_height))
            sketch_arr = np.array(sketch_pil, dtype=np.float32) / 255.0

            img_pil = Image.open(full_img_path).convert('RGB')
            img_pil = img_pil.resize((img_width, img_height))
            img_arr = np.array(img_pil, dtype=np.float32) / 255.0
            
            images.append(img_arr)
            sketches.append(sketch_arr)
            labels.append(img_id)
    
    return np.array(images, dtype=np.float32), np.array(sketches, dtype=np.float32), np.array(labels)

# Load training and validation data
train_images, train_sketches, train_labels = load_data(train_imgs_path, train_sketchs_path)
val_images, val_sketches, val_labels = load_data(val_imgs_path, val_sketchs_path)
print("Training samples:", train_images.shape)
print("Validation samples:", val_images.shape)
# Out:
# Training samples: (3000, 64, 64, 3)
# Validation samples: (466, 64, 64, 3)

# %%
def embedding_network(input_shape=(64, 64, 1), embedding_dim=128, model_name="cnn_encoder"):
    inputs = layers.Input(shape=input_shape)
    
    # Initial convolution block
    x = layers.Conv2D(64, (3,3), padding="same", use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(64, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)  # Output shape: (32, 32, 64)
    
    # Residual block 1
    shortcut = x
    x = layers.Conv2D(128, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(128, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    # Adjust shortcut to match number of filters (128)
    shortcut = layers.Conv2D(128, (1,1), padding="same", use_bias=False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)  # Output shape: (16, 16, 128)
    
    # Residual block 2
    shortcut = x
    x = layers.Conv2D(256, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(256, (3,3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    # Adjust shortcut to match number of filters (256)
    shortcut = layers.Conv2D(256, (1,1), padding="same", use_bias=False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)  # Output shape: (8, 8, 256)
    
    # Global average pooling to flatten spatial dimensions
    x = layers.GlobalAveragePooling2D()(x)
    
    # Final dense layer to produce the embedding vector
    x = layers.Dense(embedding_dim, use_bias=False)(x)
    outputs = tf.math.l2_normalize(x, axis=1)
    
    return models.Model(inputs, outputs, name=model_name)
img_shape = (img_height, img_width, channels)
sketch_shape = (img_height, img_width, channels)


image_encoder = embedding_network(img_shape, model_name='image_encoder')
sketch_encoder = embedding_network(sketch_shape, model_name='sketch_encoder')

# %%
from tensorflow.keras.optimizers import Adam

# Siamese-like model
img_input = Input(img_shape)
sketch_input = Input(img_shape)

img_emb = image_encoder(img_input)
sketch_emb = sketch_encoder(sketch_input)

# Cosine similarity-based loss
def cosine_similarity_loss(y_true, y_pred):
    img_emb, sketch_emb = y_pred[:, :128], y_pred[:, 128:]
    cosine_sim = tf.reduce_sum(img_emb * sketch_emb, axis=1)
    return 1 - cosine_sim  # minimize distance => maximize similarity

combined_output = tf.keras.layers.concatenate([img_emb, sketch_emb])

siamese_model = Model([img_input, sketch_input], combined_output)
siamese_model.compile(optimizer=Adam(1e-4), loss=cosine_similarity_loss)

# Dummy labels for compatibility
dummy_labels = np.zeros((train_images.shape[0], 1))

# Train the model
siamese_model.fit(
    [train_images, train_sketches],
    dummy_labels,
    epochs=20,
    batch_size=8,
    validation_data=([val_images, val_sketches], np.zeros((val_images.shape[0], 1)))
)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 16s 14ms/step - loss: 0.0349 - val_loss: 0.0412
# Epoch 2/20
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 3/20
# 375/375 [==============================] - 5s 13ms/step - loss: 9.1339e-04 - val_loss: 0.0011
# Epoch 4/20
# 375/375 [==============================] - 5s 13ms/step - loss: 6.3319e-04 - val_loss: 8.4675e-04
# Epoch 5/20
# 375/375 [==============================] - 5s 13ms/step - loss: 4.6677e-04 - val_loss: 6.4201e-04
# Epoch 6/20
# 375/375 [==============================] - 5s 13ms/step - loss: 3.5818e-04 - val_loss: 5.0959e-04
# Epoch 7/20
# 375/375 [==============================] - 8s 21ms/step - loss: 2.8461e-04 - val_loss: 4.0658e-04
# Epoch 8/20
# 375/375 [==============================] - 9s 24ms/step - loss: 2.2838e-04 - val_loss: 3.9088e-04
# Epoch 9/20
# 375/375 [==============================] - 8s 23ms/step - loss: 1.8963e-04 - val_loss: 3.1139e-04
# Epoch 10/20
# 375/375 [==============================] - 8s 20ms/step - loss: 1.5923e-04 - val_loss: 3.2005e-04
# Epoch 11/20
# 375/375 [==============================] - 8s 22ms/step - loss: 1.3269e-04 - val_loss: 2.2398e-04
# Epoch 12/20
# 375/375 [==============================] - 15s 41ms/step - loss: 1.1322e-04 - val_loss: 1.9116e-04
# Epoch 13/20
# 375/375 [==============================] - 16s 42ms/step - loss: 9.7249e-05 - val_loss: 1.9886e-04
# Epoch 14/20
# 375/375 [==============================] - 12s 31ms/step - loss: 8.4062e-05 - val_loss: 1.6835e-04
# Epoch 15/20
# 375/375 [==============================] - 24s 64ms/step - loss: 7.3380e-05 - val_loss: 1.3453e-04
# Epoch 16/20
# 375/375 [==============================] - 15s 41ms/step - loss: 6.3244e-05 - val_loss: 1.2634e-04
# Epoch 17/20
# 375/375 [==============================] - 9s 23ms/step - loss: 5.6326e-05 - val_loss: 1.2807e-04
# Epoch 18/20
# 375/375 [==============================] - 11s 30ms/step - loss: 5.0208e-05 - val_loss: 1.0906e-04
# Epoch 19/20
#  86/375 [=====>........................] - ETA: 4s - loss: 4.5183e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 25
#      22 dummy_labels = np.zeros((train_images.shape[0], 1))
#      24 # Train the model
# ---> 25 siamese_model.fit(
#      26     [train_images, train_sketches],
#      27     dummy_labels,
#      28     epochs=20,
#      29     batch_size=8,
#      30     validation_data=([val_images, val_sketches], np.zeros((val_images.shape[0], 1)))
#      31 )
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\engine\training.py:1198, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1196 logs = tmp_logs  # No error, now safe to assign to logs.
#    1197 end_step = step + data_handler.step_increment
# -> 1198 callbacks.on_train_batch_end(end_step, logs)
#    1199 if self.stop_training:
#    1200   break
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\callbacks.py:456, in CallbackList.on_train_batch_end(self, batch, logs)
#     449 """Calls the `on_train_batch_end` methods of its callbacks.
#     450
#     451 Args:
#     452     batch: Integer, index of batch within the current epoch.
#     453     logs: Dict. Aggregated metric results up until this batch.
#     454 """
#     455 if self._should_call_train_batch_hooks:
# --> 456   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\callbacks.py:316, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     314   self._call_batch_begin_hook(mode, batch, logs)
#     315 elif hook == 'end':
# --> 316   self._call_batch_end_hook(mode, batch, logs)
#     317 else:
#     318   raise ValueError('Unrecognized hook: {}'.format(hook))
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\callbacks.py:336, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     333   batch_time = time.time() - self._batch_start_time
#     334   self._batch_times.append(batch_time)
# --> 336 self._call_batch_hook_helper(hook_name, batch, logs)
#     338 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     339   end_hook_name = hook_name
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\callbacks.py:374, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     372 for callback in self.callbacks:
#     373   hook = getattr(callback, hook_name)
# --> 374   hook(batch, logs)
#     376 if self._check_timing:
#     377   if hook_name not in self._hook_times:
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\callbacks.py:1052, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1051 def on_train_batch_end(self, batch, logs=None):
# -> 1052   self._batch_update_progbar(batch, logs)
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\callbacks.py:1124, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1120   self.seen += add_seen
#    1122 if self.verbose == 1:
#    1123   # Only block async when verbose = 1.
# -> 1124   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1125   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py:529, in sync_to_numpy_or_python_type(tensors)
#     526     return x.item() if np.ndim(x) == 0 else x
#     527   return t  # Don't turn ragged or sparse tensors to NumPy.
# --> 529 return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py:525, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     523 def _to_single_numpy_or_python_type(t):
#     524   if isinstance(t, ops.Tensor):
# --> 525     x = t.numpy()
#     526     return x.item() if np.ndim(x) == 0 else x
#     527   return t
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\ops.py:1094, in _EagerTensorBase.numpy(self)
#    1071 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1072
#    1073 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1091     NumPy dtype.
#    1092 """
#    1093 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\ops.py:1060, in _EagerTensorBase._numpy(self)
#    1058 def _numpy(self):
#    1059   try:
# -> 1060     return self._numpy_internal()
#    1061   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062     six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
train_image_emb = image_encoder.predict(train_images, batch_size=32)
train_sketch_emb = sketch_encoder.predict(train_sketches, batch_size=32)

val_image_emb = image_encoder.predict(val_images, batch_size=32)
val_sketch_emb = sketch_encoder.predict(val_sketches, batch_size=32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input

def retrieval_network(input_dim=128, output_dim=128, model_name="retrieval_model"):
    inputs = layers.Input(shape=(input_dim,))
    
    # Initial dense block
    x = layers.Dense(512, use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)

    # Residual Dense Block 1
    shortcut = layers.Dense(512, use_bias=False)(x)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Dense(512, use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Dense(512, use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)

    # Residual Dense Block 2
    shortcut = layers.Dense(256, use_bias=False)(x)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Dense(256, use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Dense(256, use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)

    # Final embedding projection
    outputs = layers.Dense(output_dim)(x)  # no activation

    return models.Model(inputs, outputs, name=model_name)
# Example usage:
retrieval_model = retrieval_network(input_dim=train_sketch_emb.shape[1],
                                    output_dim=train_image_emb.shape[1])

retrieval_model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse')

# %%
retrieval_model.fit(
    train_sketch_emb, train_image_emb,
    epochs=50,
    batch_size=16,
    validation_data=(val_sketch_emb, val_image_emb)
)
# Out:
# Epoch 1/50
# 188/188 [==============================] - 2s 7ms/step - loss: 0.8212 - val_loss: 0.1062
# Epoch 2/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5221 - val_loss: 0.0807
# Epoch 3/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.2948 - val_loss: 0.0510
# Epoch 4/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.1324 - val_loss: 0.0426
# Epoch 5/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0623 - val_loss: 0.0376
# Epoch 6/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0352 - val_loss: 0.0245
# Epoch 7/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0246 - val_loss: 0.0174
# Epoch 8/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0182 - val_loss: 0.0129
# Epoch 9/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0150 - val_loss: 0.0098
# Epoch 10/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0128 - val_loss: 0.0083
# Epoch 11/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0102 - val_loss: 0.0065
# Epoch 12/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0087 - val_loss: 0.0050
# Epoch 13/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0072 - val_loss: 0.0042
# Epoch 14/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 15/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0030
# Epoch 16/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0048 - val_loss: 0.0029
# Epoch 17/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 18/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 19/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 20/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 21/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 22/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 23/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0020 - val_loss: 9.6317e-04
# Epoch 24/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 8.1719e-04
# Epoch 25/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 6.6456e-04
# Epoch 26/50
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 5.7268e-04
# Epoch 27/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 4.9538e-04
# Epoch 28/50
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 3.9012e-04
# Epoch 29/50
# 188/188 [==============================] - 1s 6ms/step - loss: 9.1743e-04 - val_loss: 3.3328e-04
# Epoch 30/50
# 188/188 [==============================] - 1s 5ms/step - loss: 8.3837e-04 - val_loss: 2.7790e-04
# Epoch 31/50
# 188/188 [==============================] - 1s 5ms/step - loss: 7.2574e-04 - val_loss: 2.3151e-04
# Epoch 32/50
# 188/188 [==============================] - 1s 5ms/step - loss: 6.7593e-04 - val_loss: 1.9473e-04
# Epoch 33/50
# 188/188 [==============================] - 1s 5ms/step - loss: 6.1850e-04 - val_loss: 1.6220e-04
# Epoch 34/50
# 188/188 [==============================] - 1s 6ms/step - loss: 5.1945e-04 - val_loss: 1.3737e-04
# Epoch 35/50
# 188/188 [==============================] - 1s 6ms/step - loss: 4.7560e-04 - val_loss: 1.1792e-04
# Epoch 36/50
# 188/188 [==============================] - 1s 6ms/step - loss: 4.7190e-04 - val_loss: 1.0168e-04
# Epoch 37/50
# 188/188 [==============================] - 1s 6ms/step - loss: 4.0621e-04 - val_loss: 8.8805e-05
# Epoch 38/50
# 188/188 [==============================] - 1s 6ms/step - loss: 3.7540e-04 - val_loss: 7.5466e-05
# Epoch 39/50
# 188/188 [==============================] - 1s 6ms/step - loss: 3.2323e-04 - val_loss: 6.7996e-05
# Epoch 40/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.6211e-04 - val_loss: 5.9082e-05
# Epoch 41/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.6212e-04 - val_loss: 5.3970e-05
# Epoch 42/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.1778e-04 - val_loss: 4.9475e-05
# Epoch 43/50
# 188/188 [==============================] - 1s 6ms/step - loss: 2.2650e-04 - val_loss: 4.5376e-05
# Epoch 44/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.9894e-04 - val_loss: 4.1829e-05
# Epoch 45/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.6684e-04 - val_loss: 3.8093e-05
# Epoch 46/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.6762e-04 - val_loss: 3.7958e-05
# Epoch 47/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.4513e-04 - val_loss: 3.4143e-05
# Epoch 48/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.2873e-04 - val_loss: 3.2480e-05
# Epoch 49/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.1891e-04 - val_loss: 2.9903e-05
# Epoch 50/50
# 188/188 [==============================] - 1s 6ms/step - loss: 1.2053e-04 - val_loss: 3.0821e-05

# %%
# Predict image embeddings from sketch embeddings
predicted_img_emb = retrieval_model.predict(val_sketch_emb)

# Now find closest embeddings in gallery using efficient distance calculation:
from sklearn.metrics.pairwise import euclidean_distances

distances = euclidean_distances(predicted_img_emb, val_image_emb)
top_k = 5  # choose top-5 or any K you prefer

# Get top-K predictions for each sketch
top_k_indices = np.argsort(distances, axis=1)[:, :top_k]

# Calculate recall metrics
correct_matches = np.arange(len(val_sketch_emb)).reshape(-1,1)
recall_at_k = np.mean([correct_matches[i] in top_k_indices[i] for i in range(len(val_sketch_emb))])

print(f"Recall@{top_k}: {recall_at_k:.4f}")
# Out:
# Recall@5: 0.0215

# %%
n_samples_fit = gallery_embeddings.shape[0]
n_neighbors = min(1250, n_samples_fit)

nbrs = NearestNeighbors(n_neighbors=n_neighbors).fit(gallery_embeddings)

count_recall = np.zeros(n_neighbors, dtype=int)
num_queries = val_sketches.shape[0]

# Compute embeddings for sketches (queries)
query_embeddings = sketch_encoder.predict(val_sketches, batch_size=32)

for idx, query_emb in enumerate(query_embeddings):
    distances, indices = nbrs.kneighbors([query_emb])
    correct_idx = idx  # assuming data is matched by index
    
    rank_found = np.where(indices[0] == correct_idx)[0]
    if len(rank_found) > 0:
        rank = rank_found[0]
        count_recall[rank] += 1
        print(f"Query {idx}: Found correct match at rank {rank+1}")
    else:
        print(f"Query {idx}: Not found in top {n_neighbors}.")

# Calculate cumulative recall
cumulative_recall = np.cumsum(count_recall)

# Safely computing recall metrics with checks:
recall_at_1 = cumulative_recall[0] / num_queries if n_neighbors >= 1 else 0
recall_at_5 = cumulative_recall[4] / num_queries if n_neighbors >= 5 else 0
recall_at_10 = cumulative_recall[9] / num_queries if n_neighbors >= 10 else 0

print(f"\nRecall@1: {recall_at_1:.4f}")
print(f"Recall@5: {recall_at_5:.4f}")
print(f"Recall@10: {recall_at_10:.4f}")
# Out:
# Query 0: Found correct match at rank 301
# Query 1: Found correct match at rank 438
# Query 2: Found correct match at rank 455
# Query 3: Found correct match at rank 118
# Query 4: Found correct match at rank 332
# Query 5: Found correct match at rank 29
# Query 6: Found correct match at rank 91
# Query 7: Found correct match at rank 151
# Query 8: Found correct match at rank 107
# Query 9: Found correct match at rank 211
# Query 10: Found correct match at rank 389
# Query 11: Found correct match at rank 81
# Query 12: Found correct match at rank 450
# Query 13: Found correct match at rank 47
# Query 14: Found correct match at rank 90
# Query 15: Found correct match at rank 312
# Query 16: Found correct match at rank 324
# Query 17: Found correct match at rank 283
# Query 18: Found correct match at rank 403
# Query 19: Found correct match at rank 153
# Query 20: Found correct match at rank 8
# Query 21: Found correct match at rank 230
# Query 22: Found correct match at rank 130
# Query 23: Found correct match at rank 377
# Query 24: Found correct match at rank 50
# Query 25: Found correct match at rank 130
# Query 26: Found correct match at rank 240
# Query 27: Found correct match at rank 233
# Query 28: Found correct match at rank 145
# Query 29: Found correct match at rank 345
# Query 30: Found correct match at rank 7
# Query 31: Found correct match at rank 262
# Query 32: Found correct match at rank 132
# Query 33: Found correct match at rank 295
# Query 34: Found correct match at rank 19
# Query 35: Found correct match at rank 1
# Query 36: Found correct match at rank 34
# Query 37: Found correct match at rank 52
# Query 38: Found correct match at rank 205
# Query 39: Found correct match at rank 349
# Query 40: Found correct match at rank 163
# Query 41: Found correct match at rank 260
# Query 42: Found correct match at rank 199
# Query 43: Found correct match at rank 185
# Query 44: Found correct match at rank 4
# Query 45: Found correct match at rank 384
# Query 46: Found correct match at rank 346
# Query 47: Found correct match at rank 94
# Query 48: Found correct match at rank 306
# Query 49: Found correct match at rank 288
# Query 50: Found correct match at rank 13
# Query 51: Found correct match at rank 30
# Query 52: Found correct match at rank 64
# Query 53: Found correct match at rank 47
# Query 54: Found correct match at rank 35
# Query 55: Found correct match at rank 77
# Query 56: Found correct match at rank 298
# Query 57: Found correct match at rank 322
# Query 58: Found correct match at rank 373
# Query 59: Found correct match at rank 301
# Query 60: Found correct match at rank 264
# Query 61: Found correct match at rank 346
# Query 62: Found correct match at rank 38
# Query 63: Found correct match at rank 144
# Query 64: Found correct match at rank 187
# Query 65: Found correct match at rank 26
# Query 66: Found correct match at rank 60
# Query 67: Found correct match at rank 93
# Query 68: Found correct match at rank 179
# Query 69: Found correct match at rank 232
# Query 70: Found correct match at rank 269
# Query 71: Found correct match at rank 131
# Query 72: Found correct match at rank 421
# Query 73: Found correct match at rank 381
# Query 74: Found correct match at rank 325
# Query 75: Found correct match at rank 296
# Query 76: Found correct match at rank 237
# Query 77: Found correct match at rank 164
# Query 78: Found correct match at rank 397
# Query 79: Found correct match at rank 169
# Query 80: Found correct match at rank 416
# Query 81: Found correct match at rank 431
# Query 82: Found correct match at rank 156
# Query 83: Found correct match at rank 41
# Query 84: Found correct match at rank 328
# Query 85: Found correct match at rank 291
# Query 86: Found correct match at rank 271
# Query 87: Found correct match at rank 405
# Query 88: Found correct match at rank 11
# Query 89: Found correct match at rank 199
# Query 90: Found correct match at rank 106
# Query 91: Found correct match at rank 248
# Query 92: Found correct match at rank 389
# Query 93: Found correct match at rank 195
# Query 94: Found correct match at rank 136
# Query 95: Found correct match at rank 433
# Query 96: Found correct match at rank 244
# Query 97: Found correct match at rank 170
# Query 98: Found correct match at rank 342
# Query 99: Found correct match at rank 99
# Query 100: Found correct match at rank 6
# Query 101: Found correct match at rank 214
# Query 102: Found correct match at rank 250
# Query 103: Found correct match at rank 139
# Query 104: Found correct match at rank 169
# Query 105: Found correct match at rank 208
# Query 106: Found correct match at rank 404
# Query 107: Found correct match at rank 352
# Query 108: Found correct match at rank 415
# Query 109: Found correct match at rank 26
# Query 110: Found correct match at rank 104
# Query 111: Found correct match at rank 91
# Query 112: Found correct match at rank 33
# Query 113: Found correct match at rank 65
# Query 114: Found correct match at rank 8
# Query 115: Found correct match at rank 121
# Query 116: Found correct match at rank 169
# Query 117: Found correct match at rank 275
# Query 118: Found correct match at rank 40
# Query 119: Found correct match at rank 366
# Query 120: Found correct match at rank 158
# Query 121: Found correct match at rank 54
# Query 122: Found correct match at rank 346
# Query 123: Found correct match at rank 418
# Query 124: Found correct match at rank 54
# Query 125: Found correct match at rank 381
# Query 126: Found correct match at rank 168
# Query 127: Found correct match at rank 274
# Query 128: Found correct match at rank 255
# Query 129: Found correct match at rank 237
# Query 130: Found correct match at rank 95
# Query 131: Found correct match at rank 380
# Query 132: Found correct match at rank 198
# Query 133: Found correct match at rank 248
# Query 134: Found correct match at rank 446
# Query 135: Found correct match at rank 25
# Query 136: Found correct match at rank 69
# Query 137: Found correct match at rank 411
# Query 138: Found correct match at rank 115
# Query 139: Found correct match at rank 74
# Query 140: Found correct match at rank 177
# Query 141: Found correct match at rank 64
# Query 142: Found correct match at rank 55
# Query 143: Found correct match at rank 143
# Query 144: Found correct match at rank 352
# Query 145: Found correct match at rank 151
# Query 146: Found correct match at rank 28
# Query 147: Found correct match at rank 288
# Query 148: Found correct match at rank 283
# Query 149: Found correct match at rank 280
# Query 150: Found correct match at rank 92
# Query 151: Found correct match at rank 154
# Query 152: Found correct match at rank 40
# Query 153: Found correct match at rank 390
# Query 154: Found correct match at rank 24
# Query 155: Found correct match at rank 140
# Query 156: Found correct match at rank 8
# Query 157: Found correct match at rank 409
# Query 158: Found correct match at rank 34
# Query 159: Found correct match at rank 320
# Query 160: Found correct match at rank 409
# Query 161: Found correct match at rank 46
# Query 162: Found correct match at rank 118
# Query 163: Found correct match at rank 415
# Query 164: Found correct match at rank 285
# Query 165: Found correct match at rank 407
# Query 166: Found correct match at rank 447
# Query 167: Found correct match at rank 52
# Query 168: Found correct match at rank 41
# Query 169: Found correct match at rank 265
# Query 170: Found correct match at rank 215
# Query 171: Found correct match at rank 145
# Query 172: Found correct match at rank 417
# Query 173: Found correct match at rank 400
# Query 174: Found correct match at rank 301
# Query 175: Found correct match at rank 254
# Query 176: Found correct match at rank 270
# Query 177: Found correct match at rank 297
# Query 178: Found correct match at rank 245
# Query 179: Found correct match at rank 37
# Query 180: Found correct match at rank 338
# Query 181: Found correct match at rank 220
# Query 182: Found correct match at rank 451
# Query 183: Found correct match at rank 94
# Query 184: Found correct match at rank 15
# Query 185: Found correct match at rank 115
# Query 186: Found correct match at rank 23
# Query 187: Found correct match at rank 153
# Query 188: Found correct match at rank 357
# Query 189: Found correct match at rank 1
# Query 190: Found correct match at rank 323
# Query 191: Found correct match at rank 45
# Query 192: Found correct match at rank 311
# Query 193: Found correct match at rank 226
# Query 194: Found correct match at rank 178
# Query 195: Found correct match at rank 76
# Query 196: Found correct match at rank 4
# Query 197: Found correct match at rank 394
# Query 198: Found correct match at rank 375
# Query 199: Found correct match at rank 389
# Query 200: Found correct match at rank 351
# Query 201: Found correct match at rank 127
# Query 202: Found correct match at rank 116
# Query 203: Found correct match at rank 285
# Query 204: Found correct match at rank 374
# Query 205: Found correct match at rank 374
# Query 206: Found correct match at rank 421
# Query 207: Found correct match at rank 286
# Query 208: Found correct match at rank 159
# Query 209: Found correct match at rank 133
# Query 210: Found correct match at rank 137
# Query 211: Found correct match at rank 232
# Query 212: Found correct match at rank 80
# Query 213: Found correct match at rank 165
# Query 214: Found correct match at rank 384
# Query 215: Found correct match at rank 313
# Query 216: Found correct match at rank 338
# Query 217: Found correct match at rank 81
# Query 218: Found correct match at rank 199
# Query 219: Found correct match at rank 249
# Query 220: Found correct match at rank 25
# Query 221: Found correct match at rank 143
# Query 222: Found correct match at rank 291
# Query 223: Found correct match at rank 407
# Query 224: Found correct match at rank 194
# Query 225: Found correct match at rank 202
# Query 226: Found correct match at rank 440
# Query 227: Found correct match at rank 381
# Query 228: Found correct match at rank 433
# Query 229: Found correct match at rank 97
# Query 230: Found correct match at rank 398
# Query 231: Found correct match at rank 49
# Query 232: Found correct match at rank 226
# Query 233: Found correct match at rank 47
# Query 234: Found correct match at rank 78
# Query 235: Found correct match at rank 56
# Query 236: Found correct match at rank 292
# Query 237: Found correct match at rank 175
# Query 238: Found correct match at rank 292
# Query 239: Found correct match at rank 47
# Query 240: Found correct match at rank 137
# Query 241: Found correct match at rank 341
# Query 242: Found correct match at rank 328
# Query 243: Found correct match at rank 76
# Query 244: Found correct match at rank 63
# Query 245: Found correct match at rank 338
# Query 246: Found correct match at rank 97
# Query 247: Found correct match at rank 140
# Query 248: Found correct match at rank 248
# Query 249: Found correct match at rank 363
# Query 250: Found correct match at rank 102
# Query 251: Found correct match at rank 219
# Query 252: Found correct match at rank 256
# Query 253: Found correct match at rank 261
# Query 254: Found correct match at rank 152
# Query 255: Found correct match at rank 466
# Query 256: Found correct match at rank 217
# Query 257: Found correct match at rank 32
# Query 258: Found correct match at rank 38
# Query 259: Found correct match at rank 236
# Query 260: Found correct match at rank 325
# Query 261: Found correct match at rank 346
# Query 262: Found correct match at rank 212
# Query 263: Found correct match at rank 121
# Query 264: Found correct match at rank 330
# Query 265: Found correct match at rank 321
# Query 266: Found correct match at rank 27
# Query 267: Found correct match at rank 174
# Query 268: Found correct match at rank 280
# Query 269: Found correct match at rank 165
# Query 270: Found correct match at rank 237
# Query 271: Found correct match at rank 238
# Query 272: Found correct match at rank 330
# Query 273: Found correct match at rank 368
# Query 274: Found correct match at rank 398
# Query 275: Found correct match at rank 111
# Query 276: Found correct match at rank 223
# Query 277: Found correct match at rank 99
# Query 278: Found correct match at rank 323
# Query 279: Found correct match at rank 139
# Query 280: Found correct match at rank 105
# Query 281: Found correct match at rank 463
# Query 282: Found correct match at rank 180
# Query 283: Found correct match at rank 383
# Query 284: Found correct match at rank 458
# Query 285: Found correct match at rank 341
# Query 286: Found correct match at rank 175
# Query 287: Found correct match at rank 297
# Query 288: Found correct match at rank 313
# Query 289: Found correct match at rank 441
# Query 290: Found correct match at rank 91
# Query 291: Found correct match at rank 324
# Query 292: Found correct match at rank 387
# Query 293: Found correct match at rank 397
# Query 294: Found correct match at rank 124
# Query 295: Found correct match at rank 267
# Query 296: Found correct match at rank 208
# Query 297: Found correct match at rank 443
# Query 298: Found correct match at rank 41
# Query 299: Found correct match at rank 425
# Query 300: Found correct match at rank 138
# Query 301: Found correct match at rank 274
# Query 302: Found correct match at rank 247
# Query 303: Found correct match at rank 299
# Query 304: Found correct match at rank 170
# Query 305: Found correct match at rank 234
# Query 306: Found correct match at rank 459
# Query 307: Found correct match at rank 292
# Query 308: Found correct match at rank 385
# Query 309: Found correct match at rank 452
# Query 310: Found correct match at rank 85
# Query 311: Found correct match at rank 316
# Query 312: Found correct match at rank 307
# Query 313: Found correct match at rank 355
# Query 314: Found correct match at rank 270
# Query 315: Found correct match at rank 195
# Query 316: Found correct match at rank 342
# Query 317: Found correct match at rank 125
# Query 318: Found correct match at rank 46
# Query 319: Found correct match at rank 28
# Query 320: Found correct match at rank 307
# Query 321: Found correct match at rank 289
# Query 322: Found correct match at rank 367
# Query 323: Found correct match at rank 307
# Query 324: Found correct match at rank 412
# Query 325: Found correct match at rank 210
# Query 326: Found correct match at rank 273
# Query 327: Found correct match at rank 102
# Query 328: Found correct match at rank 387
# Query 329: Found correct match at rank 281
# Query 330: Found correct match at rank 276
# Query 331: Found correct match at rank 425
# Query 332: Found correct match at rank 224
# Query 333: Found correct match at rank 352
# Query 334: Found correct match at rank 133
# Query 335: Found correct match at rank 71
# Query 336: Found correct match at rank 123
# Query 337: Found correct match at rank 11
# Query 338: Found correct match at rank 444
# Query 339: Found correct match at rank 23
# Query 340: Found correct match at rank 427
# Query 341: Found correct match at rank 305
# Query 342: Found correct match at rank 454
# Query 343: Found correct match at rank 263
# Query 344: Found correct match at rank 248
# Query 345: Found correct match at rank 105
# Query 346: Found correct match at rank 82
# Query 347: Found correct match at rank 294
# Query 348: Found correct match at rank 240
# Query 349: Found correct match at rank 362
# Query 350: Found correct match at rank 255
# Query 351: Found correct match at rank 114
# Query 352: Found correct match at rank 296
# Query 353: Found correct match at rank 244
# Query 354: Found correct match at rank 205
# Query 355: Found correct match at rank 437
# Query 356: Found correct match at rank 253
# Query 357: Found correct match at rank 370
# Query 358: Found correct match at rank 133
# Query 359: Found correct match at rank 323
# Query 360: Found correct match at rank 24
# Query 361: Found correct match at rank 428
# Query 362: Found correct match at rank 242
# Query 363: Found correct match at rank 299
# Query 364: Found correct match at rank 408
# Query 365: Found correct match at rank 383
# Query 366: Found correct match at rank 416
# Query 367: Found correct match at rank 252
# Query 368: Found correct match at rank 394
# Query 369: Found correct match at rank 348
# Query 370: Found correct match at rank 304
# Query 371: Found correct match at rank 363
# Query 372: Found correct match at rank 111
# Query 373: Found correct match at rank 264
# Query 374: Found correct match at rank 465
# Query 375: Found correct match at rank 412
# Query 376: Found correct match at rank 438
# Query 377: Found correct match at rank 231
# Query 378: Found correct match at rank 421
# Query 379: Found correct match at rank 35
# Query 380: Found correct match at rank 312
# Query 381: Found correct match at rank 300
# Query 382: Found correct match at rank 422
# Query 383: Found correct match at rank 274
# Query 384: Found correct match at rank 261
# Query 385: Found correct match at rank 256
# Query 386: Found correct match at rank 181
# Query 387: Found correct match at rank 88
# Query 388: Found correct match at rank 98
# Query 389: Found correct match at rank 237
# Query 390: Found correct match at rank 393
# Query 391: Found correct match at rank 395
# Query 392: Found correct match at rank 402
# Query 393: Found correct match at rank 75
# Query 394: Found correct match at rank 274
# Query 395: Found correct match at rank 87
# Query 396: Found correct match at rank 295
# Query 397: Found correct match at rank 185
# Query 398: Found correct match at rank 398
# Query 399: Found correct match at rank 464
# Query 400: Found correct match at rank 348
# Query 401: Found correct match at rank 70
# Query 402: Found correct match at rank 78
# Query 403: Found correct match at rank 446
# Query 404: Found correct match at rank 245
# Query 405: Found correct match at rank 75
# Query 406: Found correct match at rank 363
# Query 407: Found correct match at rank 93
# Query 408: Found correct match at rank 95
# Query 409: Found correct match at rank 289
# Query 410: Found correct match at rank 292
# Query 411: Found correct match at rank 455
# Query 412: Found correct match at rank 100
# Query 413: Found correct match at rank 41
# Query 414: Found correct match at rank 310
# Query 415: Found correct match at rank 457
# Query 416: Found correct match at rank 184
# Query 417: Found correct match at rank 427
# Query 418: Found correct match at rank 429
# Query 419: Found correct match at rank 174
# Query 420: Found correct match at rank 274
# Query 421: Found correct match at rank 308
# Query 422: Found correct match at rank 324
# Query 423: Found correct match at rank 464
# Query 424: Found correct match at rank 15
# Query 425: Found correct match at rank 434
# Query 426: Found correct match at rank 331
# Query 427: Found correct match at rank 222
# Query 428: Found correct match at rank 403
# Query 429: Found correct match at rank 74
# Query 430: Found correct match at rank 277
# Query 431: Found correct match at rank 449
# Query 432: Found correct match at rank 367
# Query 433: Found correct match at rank 388
# Query 434: Found correct match at rank 113
# Query 435: Found correct match at rank 378
# Query 436: Found correct match at rank 184
# Query 437: Found correct match at rank 119
# Query 438: Found correct match at rank 196
# Query 439: Found correct match at rank 127
# Query 440: Found correct match at rank 345
# Query 441: Found correct match at rank 315
# Query 442: Found correct match at rank 109
# Query 443: Found correct match at rank 106
# Query 444: Found correct match at rank 371
# Query 445: Found correct match at rank 454
# Query 446: Found correct match at rank 329
# Query 447: Found correct match at rank 162
# Query 448: Found correct match at rank 408
# Query 449: Found correct match at rank 331
# Query 450: Found correct match at rank 87
# Query 451: Found correct match at rank 389
# Query 452: Found correct match at rank 388
# Query 453: Found correct match at rank 219
# Query 454: Found correct match at rank 13
# Query 455: Found correct match at rank 427
# Query 456: Found correct match at rank 237
# Query 457: Found correct match at rank 12
# Query 458: Found correct match at rank 185
# Query 459: Found correct match at rank 18
# Query 460: Found correct match at rank 225
# Query 461: Found correct match at rank 76
# Query 462: Found correct match at rank 138
# Query 463: Found correct match at rank 256
# Query 464: Found correct match at rank 360
# Query 465: Found correct match at rank 180
#
# Recall@1: 0.0043
# Recall@5: 0.0086
# Recall@10: 0.0193
